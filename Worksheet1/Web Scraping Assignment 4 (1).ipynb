# %%
#importing necessary libraries
import selenium
import pandas as pd
from bs4 import BeautifulSoup
import time

#Importing requests
import requests

# importing regex
import re

# Importing selenium webdriver
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia:Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
#Let's first connect to the webdriver
driver=webdriver.Chrome(r'C:\Users\Chandru\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
#getting the specified the url
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
time.sleep(3)

# %%
#Creating empty list
Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

# %%
#scraping the data of rank
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
#Scraping data of video names
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

# %%
#Scraping data of artist name
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')

# %%
#Scraping data of upload dates
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:        
    Upload_date.append('-')

# %%
#Scraping data of views
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')

# %%
#DATA FRAMEING
Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_date
Youtube['Views'] = Views

# %%
#Printing data frame
Youtube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[21]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[22]
# 8    9.                "Phonics Song with Two Words"[23]
# 9   10.                                "Uptown Funk"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                             "Dame Tu Cosita"[30]
# 12  13.                          "Wheels on the Bus"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                                      "Sorry"[34]
# 16  17.                             "Counting Stars"[35]
# 17  18.                          "Thinking Out Loud"[36]
# 18  19.                             "Girls Like You"[37]
# 19  20.                                      "Faded"[38]
# 20  21.                                 "Dark Horse"[39]
# 21  22.                                     "Axel F"[40]
# 22  23.                                 "Let Her Go"[41]
# 23  24.                                   "Bailando"[42]
# 24  25.                                    "Lean On"[43]
# 25  26.                               "Shake It Off"[44]
# 26  27.                        "Baa Baa Black Sheep"[45]
# 27  28.                                    "Perfect"[46]
# 28  29.           "Waka Waka (This Time for Africa)"[47]
# 29  30.                                   "Mi Gente"[48]
#
#                                          Artist      Uploaded Date  Views
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  10.18
# 1                                    Luis Fonsi   January 12, 2017   7.74
# 2                                   LooLoo Kids    October 8, 2016   6.16
# 3                                    Ed Sheeran   January 30, 2017   5.61
# 4                                   Wiz Khalifa      April 6, 2015   5.41
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018   4.97
# 6                                   Miroshka TV  February 27, 2018   4.56
# 7                                    Get Movies   January 31, 2012   4.48
# 8                                     ChuChu TV      March 6, 2014   4.46
# 9                                   Mark Ronson  November 19, 2014   4.46
# 10                                          Psy      July 15, 2012   4.34
# 11                                    El Chombo      April 5, 2018   3.84
# 12                   Cocomelon – Nursery Rhymes       May 24, 2018   3.66
# 13                                     Maroon 5   January 14, 2015   3.64
# 14                                   Katy Perry  September 5, 2013   3.52
# 15                                Justin Bieber   October 22, 2015   3.51
# 16                                  OneRepublic       May 31, 2013   3.51
# 17                                   Ed Sheeran    October 7, 2014   3.40
# 18                                     Maroon 5       May 31, 2018   3.23
# 19                                  Alan Walker   December 3, 2015   3.23
# 20                                   Katy Perry  February 20, 2014   3.22
# 21                                   Crazy Frog      June 16, 2009   3.22
# 22                                    Passenger      July 25, 2012   3.17
# 23                             Enrique Iglesias     April 11, 2014   3.16
# 24                                  Major Lazer     March 22, 2015   3.16
# 25                                 Taylor Swift    August 18, 2014   3.14
# 26                   Cocomelon – Nursery Rhymes      June 25, 2018   3.12
# 27                                   Ed Sheeran   November 9, 2017   3.09
# 28                                      Shakira       June 4, 2010   3.06
# 29                                     J Balvin      June 29, 2017   3.04

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/ You need to find following details:
# A) Name
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
# Connecting to the webdriver
driver =webdriver.Chrome(r'C:\Users\Chandru\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
#getting the specified url
url = "https://www.guru99.com/"
driver.get(url)
time.sleep(3)

# %%
#Going to search bar and searching for selenium exception
ser_bar = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
ser_bar.send_keys("selenium exception handling")
ser_but = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button").click()
time.sleep(3)

# %%
#Url of selenium exception handling page
urls = driver.find_element_by_xpath("//div[@class='gsc-expansionArea']//div//a")
page_url = urls.get_attribute("href")

driver.get(page_url)
time.sleep(5)

#Scraping data of names of exceptions
Name = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[1]")[1:]:
    Name.append(i.text)
    
#Scraping data of descriptions of exceptions  
Description = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[2]")[1:]:
    Description.append(i.text)

# %%
#DATA FRAMEING
Guru=pd.DataFrame({})
Guru['Name of Exception'] = Name
Guru['Description of Exception'] = Description

# %%
#Printing data frame
Guru
# Out:
#                       Name of Exception  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                              Description of Exception
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP
#
# D) GSDP
#
# E) Share
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# Connecting to the webdriver
driver =webdriver.Chrome(r'C:\Users\Chandru\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
#getting the specified url
url = "http://statisticstimes.com/"
driver.get(url)
time.sleep(3)

# %%
#Clicking on economy section
economy = driver.find_element_by_xpath("//div[@class='navbar']//div[2]//button").click()

urls = driver.find_element_by_xpath("//div[@class='dropdown-content']//a[3]")
ineco_page = urls.get_attribute("href")
#Going to indian economy page
driver.get(ineco_page)  
time.sleep(5)

# %%
#Creating empty list
Rank = []
State = []
GSDP_1 = []
GSDP_2 = []
Share = []
GDP = []

# %%
#get the url of page containing GDP of indian states
sta_GDP = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
GDP_url = sta_GDP.get_attribute("href")

driver.get(GDP_url)
time.sleep(6)


#Scraping data of rank
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
    Rank.append(i.text)

    
#Scraping data of state name
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
    State.append(i.text)

    
# Scraping data of GSDP at current price
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
    GSDP_1.append(i.text)

    
#Scraping data of GSDP at current price
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[4]"):
    GSDP_2.append(i.text)

    
#Scraping data of Share
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[5]"):
    Share.append(i.text)

    
#Scraping data of GDP($ billion)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[6]"):
    GDP.append(i.text)

# %%
#DATA FRAMEING
StatisticsTime=pd.DataFrame({})
StatisticsTime['Rank'] = Rank
StatisticsTime['State'] = State
StatisticsTime['GSDP at current price'] = GSDP_1
StatisticsTime['GSDP at current price'] = GSDP_2
StatisticsTime['Share'] = Share
StatisticsTime['GDP($ billion)'] = GDP

# %%
#Printing the data frame
StatisticsTime
# Out:
#    Rank                      State GSDP at current price   Share  \
# 0     1                Maharashtra             2,632,792  13.94%
# 1     2                 Tamil Nadu             1,630,208   8.63%
# 2     3              Uttar Pradesh             1,584,764   8.39%
# 3     4                    Gujarat             1,502,899   7.96%
# 4     5                  Karnataka             1,493,127   7.91%
# 5     6                West Bengal             1,089,898   5.77%
# 6     7                  Rajasthan               942,586   4.99%
# 7     8             Andhra Pradesh               862,957   4.57%
# 8     9                  Telangana               861,031   4.56%
# 9    10             Madhya Pradesh               809,592   4.29%
# 10   11                     Kerala               781,653   4.14%
# 11   12                      Delhi               774,870   4.10%
# 12   13                    Haryana               734,163   3.89%
# 13   14                      Bihar               530,363   2.81%
# 14   15                     Punjab               526,376   2.79%
# 15   16                     Odisha               487,805   2.58%
# 16   17                      Assam               315,881   1.67%
# 17   18               Chhattisgarh               304,063   1.61%
# 18   19                  Jharkhand               297,204   1.57%
# 19   20                Uttarakhand               245,895   1.30%
# 20   21            Jammu & Kashmir               155,956   0.83%
# 21   22           Himachal Pradesh               153,845   0.81%
# 22   23                        Goa                73,170   0.39%
# 23   24                    Tripura                49,845   0.26%
# 24   25                 Chandigarh                42,114   0.22%
# 25   26                 Puducherry                34,433   0.18%
# 26   27                  Meghalaya                33,481   0.18%
# 27   28                     Sikkim                28,723   0.15%
# 28   29                    Manipur                27,870   0.15%
# 29   30                   Nagaland                27,283   0.14%
# 30   31          Arunachal Pradesh                24,603   0.13%
# 31   32                    Mizoram                22,287   0.12%
# 32   33  Andaman & Nicobar Islands                     -       -
#
#    GDP($ billion)
# 0         399.921
# 1         247.629
# 2         240.726
# 3         228.290
# 4         226.806
# 5         165.556
# 6         143.179
# 7         131.083
# 8         130.791
# 9         122.977
# 10        118.733
# 11        117.703
# 12        111.519
# 13         80.562
# 14         79.957
# 15         74.098
# 16         47.982
# 17         46.187
# 18         45.145
# 19         37.351
# 20         23.690
# 21         23.369
# 22         11.115
# 23          7.571
# 24          6.397
# 25          5.230
# 26          5.086
# 27          4.363
# 28          4.233
# 29          4.144
# 30          3.737
# 31          3.385
# 32              -

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used

# %%
# Connecting to the webdriver
driver =webdriver.Chrome(r'C:\Users\Chandru\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
#getting the specified url
url = "https://github.com/"
driver.get(url)
time.sleep(3)

# %%
#Getting explore button and clicking on it
explore = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary").click()

#Selecting trending option
trend_url = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

# %%
#Creating empty list
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

#Fetching urls for each repository
repository = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))

    
# Scraping Repository Title data
title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)

    
# Scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(3)
    
    
    # Scraping Repository Description data
    try:
        desc = driver.find_element_by_xpath("//p[@class='f4 my-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    # Scraping Contributors Count data
    try:
        contributor = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
        
        # Scraping Languages used data
    try:
        for i in driver.find_elements_by_xpath("//a[@class='topic-tag topic-tag-link']"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
        
#DATA FRAMEING
Github=pd.DataFrame({})
Github['Repository title'] = repository_title
Github['Repository description'] = Description
Github['Contributors count'] = Contributors
Github['Language used'] = Language
Github
# Out:
#                              Repository title  \
# 0                      BishopFox / unredacter
# 1                    alibaba / lowcode-engine
# 2                       doocs / advanced-java
# 3                       qiurunze123 / miaosha
# 4                          saadeghi / daisyui
# 5                    filecoin-project / lotus
# 6                      Anduin2017 / HowToCook
# 7          donnemartin / system-design-primer
# 8   DataTalksClub / data-engineering-zoomcamp
# 9          quenhus / uBlock-Origin-dev-filter
# 10            algorithmica-org / algorithmica
# 11   csguide-dabai / Programmer-look-at-China
# 12       OffcierCia / DeFi-Developer-Road-Map
# 13                      dair-ai / GNNs-Recipe
# 14                      LSPosed / MagiskOnWSA
# 15                           odin-lang / Odin
# 16                        google / googletest
# 17                          probml / pml-book
# 18                freeCodeCamp / freeCodeCamp
# 19                            evanw / esbuild
# 20                                obss / sahi
# 21                        laravel / framework
# 22                        libevent / libevent
# 23                littlefs-project / littlefs
# 24                         mqyqingfeng / Blog
#
#                                Repository description Contributors count  \
# 0   Never ever ever use pixelation as a redaction ...                  2
# 1                                                   -                  5
# 2   😮 Core Interview Questions & Answers For Exper...                 31
# 3                         ⭐⭐⭐⭐秒杀系统设计与实现.互联网工程师进阶与分析🙋🐓                  7
# 4                 ⭐️ ⭐️ ⭐️ ⭐️ ⭐️  Tailwind Components                 26
# 5   Implementation of the Filecoin protocol, writt...                146
# 6                                        程序员在家做饭方法指南。                 27
# 7   Learn how to design large-scale systems. Prep ...                112
# 8                       Free Data Engineering course!                 27
# 9   Filters to block and remove copycat-websites f...                 14
# 10                         New version of the website                 31
# 11                            介绍中国各二线以上城市的互联网环境以及生活成本                  2
# 12  DeFi Developer roadmap is a curated Web3.0 Dev...                 18
# 13     A recipe to study Graph Neural Networks (GNNs)                  2
# 14  Integrate Magisk root and Google Apps (OpenGAp...                 14
# 15                          Odin Programming Language                 93
# 16  GoogleTest - Google Testing and Mocking Framework                352
# 17  "Probabilistic Machine Learning" - a book seri...                  2
# 18  freeCodeCamp.org's open-source codebase and cu...              4,394
# 19  An extremely fast JavaScript and CSS bundler a...                 78
# 20  A lightweight vision library for performing la...                  8
# 21                             The Laravel Framework.              2,735
# 22                         Event notification library                196
# 23  A little fail-safe filesystem designed for mic...                 32
# 24  冴羽写博客的地方，预计写四个系列：JavaScript深入系列、JavaScript专题系列...                  2
#
#                                         Language used
# 0   [java, redis, elasticsearch, distributed-syste...
# 1   [java, redis, elasticsearch, distributed-syste...
# 2   [java, redis, elasticsearch, distributed-syste...
# 3   [java, redis, elasticsearch, distributed-syste...
# 4   [java, redis, elasticsearch, distributed-syste...
# 5   [java, redis, elasticsearch, distributed-syste...
# 6   [java, redis, elasticsearch, distributed-syste...
# 7   [java, redis, elasticsearch, distributed-syste...
# 8   [java, redis, elasticsearch, distributed-syste...
# 9   [java, redis, elasticsearch, distributed-syste...
# 10  [java, redis, elasticsearch, distributed-syste...
# 11  [java, redis, elasticsearch, distributed-syste...
# 12  [java, redis, elasticsearch, distributed-syste...
# 13  [java, redis, elasticsearch, distributed-syste...
# 14  [java, redis, elasticsearch, distributed-syste...
# 15  [java, redis, elasticsearch, distributed-syste...
# 16  [java, redis, elasticsearch, distributed-syste...
# 17  [java, redis, elasticsearch, distributed-syste...
# 18  [java, redis, elasticsearch, distributed-syste...
# 19  [java, redis, elasticsearch, distributed-syste...
# 20  [java, redis, elasticsearch, distributed-syste...
# 21  [java, redis, elasticsearch, distributed-syste...
# 22  [java, redis, elasticsearch, distributed-syste...
# 23  [java, redis, elasticsearch, distributed-syste...
# 24  [java, redis, elasticsearch, distributed-syste...

# %% [markdown]
# # 6: Scrape the details of top 100 songs on billboard.com. Url = https://www.billboard.com/
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Connecting to the webdriver
driver = webdriver.Chrome(r'C:\Users\Chandru\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
url = "https://www.billboard.com/"
driver.get(url)
time.sleep(6)
driver.maximize_window()

# %%
time.sleep(3)
Hot_song= driver.find_element_by_xpath("//li[@class='o-nav__list-item ']//a")
Hot_song.click()
time.sleep(3)

# %%
# Creating Blank List
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %%
#Scraping Song_name
song_name= driver.find_elements_by_xpath("//span[@class='chart-element__information']/span[1]")
for i in song_name:
    if i.text is None:
        Song_name.append('--')
    else:
        Song_name.append(i.text)

# %%
#Scraping Artist_name
artist_name= driver.find_elements_by_xpath("//span[@class='chart-element__information']/span[2]")
for i in artist_name:
    if i.text is None:
        Artist_name.append('--')
    else:
        Artist_name.append(i.text)

# %%
#Scraping Last_week_rank
last_week_rank= driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
for i in last_week_rank:
    if i.text is None:
        Last_week_rank.append('--')
    else:
        Last_week_rank.append(i.text)
        
#Scraping Peak_rank
peak_rank= driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
for i in peak_rank:
    if i.text is None:
        Peak_rank.append('--')
    else:
        Peak_rank.append(i.text)
        
#Scraping Weeks_on_board
weeks_on_board= driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
for i in weeks_on_board:
    if i.text is None:
        Weeks_on_board.append('--')
    else:
        Weeks_on_board.append(i.text)

Hot_Songs=pd.DataFrame({})
Hot_Songs['Song_name']=Song_name
Hot_Songs['Artist_name']=Artist_name
Hot_Songs['Last_week_rank']=Last_week_rank
Hot_Songs['Peak_rank']=Peak_rank
Hot_Songs['Weeks_on_board']=Weeks_on_board

Hot_Songs
# Out:
# Empty DataFrame
# Columns: [Song_name, Artist_name, Last_week_rank, Peak_rank, Weeks_on_board]
# Index: []

# %% [markdown]
# # 7: Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
# Connecting to the webdriver
driver = webdriver.Chrome(r'C:\Users\Chandru\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# Getting the webpage of mentioned url 
url=('https://www.naukri.com/naukri-dot-com-recruiters')
driver.get(url)
time.sleep(2)

# %%
#Fetching urls to navigate recruiter page
recruiter = driver.find_element_by_xpath("//a[@title='Search Recruiters']")
page_url = recruiter.get_attribute("href")

driver.get(page_url)
time.sleep(3)

# %%
# Fetching search button, sending keys and clicking on it
search = driver.find_element_by_xpath("//div[@class='inpWrap']//input") 
search.send_keys("Data science ")           
btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()     
time.sleep(3)

# %%
#Creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

#Scraping data of Names
for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


#Scraping data of Designation
for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
    Designation.append(i.text)
time.sleep(3)

#Scraping data of company name
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)
time.sleep(3)
    
#scraping data of Skills 
for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
    time.sleep(3)

#Scraping data of locations
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span"):
    Location.append(i.text)
time.sleep(3)

# Creating dataframe for scraped data
Naukri=pd.DataFrame({})
Naukri['Name'] = Name[:50]
Naukri['Designation'] = Designation[:50]
Naukri['Company'] = Company[:50]
Naukri['Skills'] = Skills[:50]
Naukri['Location'] = Location[:50]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Sakshi Chhikara
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# 18                             Sandhya Khandagale
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                                      Shaun Rao
# 25                                  Azahar Shaikh
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                Dhruv Dev Dubey
# 31                                         Avodha
# 32                                      Jayanth N
# 33                                    Priya Khare
# 34                                    Amit Sharma
# 35                                          Kanan
# 36                           Shashikant Chaudhary
# 37                                           Brad
# 38                                   Rutuja Pawar
# 39                            Madhusudhan Sridhar
# 40                                    Ankit Sinha
# 41                                 Gaurav Chouhan
# 42                                   Rashi Kacker
# 43                                        Ashwini
# 44                                   Balaji Kolli
# 45                                 Rajani Nagaraj
# 46                                    ROHIT Kumar
# 47                                 Amir Chowdhury
# 48                              Radha Manivasagam
# 49                                       SREEDHAR
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                 Assistant Manager HR
# 11                           HR Manager
# 12                     Executive Hiring
# 13                           Company HR
# 14                           Company HR
# 15                         HR Team Lead
# 16                           HR Manager
# 17  Senior Executive Talent Acquisition
# 18                         HR Recruiter
# 19                         HR Executive
# 20           Manager Talent Acquisition
# 21                              HR Head
# 22                           HR MANAGER
# 23                         HR Recruiter
# 24              Manager Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30             Company Recruitment Head
# 31       Business Development Associate
# 32                      Project Manager
# 33                       Senior Manager
# 34                           Consultant
# 35         senior technology instructor
# 36             HR Recruiter/HR Excutive
# 37        Manager, Technical Recruiting
# 38                  Technical Recruiter
# 39                      Erp Implementer
# 40                       Head Analytics
# 41              Chief Technical Officer
# 42                   Sr Product Manager
# 43             Director Global Delivery
# 44                           Co Founder
# 45                           HR Manager
# 46                            Architect
# 47                     Managing Partner
# 48                         HR Executive
# 49               Recruitment Consultant
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                   BIZ INFOTECNO PRIVATE LIMITED
# 11                   Infinitive Software Solutions
# 12                              Innominds Software
# 13                                        MoneyTap
# 14              QuantMagnum Technologies Pvt. Ltd.
# 15                               SocialPrachar.com
# 16                                  BISP Solutions
# 17                           Bristlecone India Ltd
# 18                 Compumatrice Multimedia Pvt Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                              Exela Technologies
# 25                 NEAL ANALYTICS SERVICES PVT LTD
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30                                    Confidential
# 31                              Nikitha Palaparthi
# 32        Dollarbird Information Services Pvt, Ltd
# 33                          Independent Consultant
# 34                                 ASCO consulting
# 35                                         NY INST
# 36  3D India Staffing Research &amp; Consulting...
# 37                                     O.C. Tanner
# 38                                   Demand Matrix
# 39                             MADHUSUDHAN SRIDHAR
# 40                                  Suntech Global
# 41                        Strategic Consulting Lab
# 42                            Impel Labs Pvt. Ltd.
# 43                                    MRP Advisers
# 44                   Saras Solutions India Pvt Ltd
# 45                                     WildJasmine
# 46                             LNT Private Limited
# 47                                     Granular.ai
# 48                                      Techcovery
# 49     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  React.js, Data Science, Java, Front End, Busin...
# 11  Oracle Dba, Data Science, Data Warehousing, ET...
# 12  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 13  Business Intelligence, Data Warehousing, Data ...
# 14  Office Administration, Hr Administration, tele...
# 15  Social Media, digital media maketing, seo, smm...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 18  Big Data, Data Science, Artificial Intelligenc...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 25  Data Science, Artificial Intelligence, Machine...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Server Administartion, Verilog, Vhdl, Digital ...
# 31  Ethical Hacking, Security Operations Center, S...
# 32  Data Analytics, Managed Services, Team Leading...
# 33  Data Science, Artificial Intelligence, analyti...
# 34  Machine Learning, Artificial Intelligence, Dat...
# 35  C, C++, Artificial Intelligence, Python, Php, ...
# 36  Relationship Management, Retail Sales, Private...
# 37                 Data Science, Software Engineering
# 38  Data Science, Big Data Analytics, Digital Mark...
# 39                  Data Science, Recruitment, Salary
# 40  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 41  Software Development, Business Intelligence, B...
# 42                   Data Science, Node.js, Angularjs
# 43  Data Science, Media Marketing, Resource Planni...
# 44  Data Analysis, Learning, Data Science, Compute...
# 45  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 46  Software Development, Core Java, Unit Testing,...
# 47  Machine Learning, Data Science, Product Manage...
# 48  Python, Artificial Intelligence, Machine Learn...
# 49  Data Science, Machine Learning, Big Data Analy...
#
#                                          Location
# 0                                    Aakash Harit
# 1                                      HR Manager
# 2                                           Delhi
# 3                            shravan Kumar Gaddam
# 4                               Company Recruiter
# 5                        Hyderabad / Secunderabad
# 6                        MARSIAN Technologies LLP
# 7                                      Company HR
# 8                                            Pune
# 9                                    Anik Agrawal
# 10                              Company Recruiter
# 11                                      Ahmedabad
# 12                                   subhas patel
# 13                                    Founder CEO
# 14                                  UK - (london)
# 15   Abhishek - Only Analytics Hiring - India and
# 16                    Recruitment Lead Consultant
# 17                              Vadodara / Baroda
# 18  Institute for Financial Management and Resear
# 19                              Programme Manager
# 20                                        Chennai
# 21                                    Balu Ramesh
# 22                               HR Administrator
# 23                                     Trivandrum
# 24                                  Asif Lucknowi
# 25                                       Director
# 26                                         Indore
# 27                                InstaFinancials
# 28                                 Human Resource
# 29                          Bengaluru / Bangalore
# 30                                Sakshi Chhikara
# 31                           Assistant Manager HR
# 32                                     Chandigarh
# 33                                 Priyanka Akiri
# 34                                     HR Manager
# 35                                      Hyderabad
# 36                                Kalpana Dumpala
# 37                               Executive Hiring
# 38                       Hyderabad / Secunderabad
# 39                                        Mubarak
# 40                                     Company HR
# 41                          Bengaluru / Bangalore
# 42                                 Kushal Rastogi
# 43                                     Company HR
# 44                                         Mumbai
# 45                             Mahesh Babu Channa
# 46                                   HR Team Lead
# 47                       Hyderabad / Secunderabad
# 48                                   Kapil Devang
# 49                                     HR Manager

# %% [markdown]
# # 8: Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
# Connecting to the webdriver
driver = webdriver.Chrome(r'C:\Users\Chandru\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url=('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/')
driver.get(url)

# %%
#Creating empty list
Book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []

#scraping book names data
for i in driver.find_elements_by_xpath("//tbody//tr/td[2]"):
    Book_name.append(i.text)

    
#Scraping author names data
for i in driver.find_elements_by_xpath("//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author_name.append(i.text)
    except NoSuchElementException:
        Author_name.append('-')
time.sleep(1)


#Scraping data of volumes sold
for i in driver.find_elements_by_xpath("//tbody/tr/td[4]"):
    Volumes_sold.append(i.text)

    
#Scraping data of publisher names
for i in driver.find_elements_by_xpath("//tbody/tr/td[5]"):
    Publisher.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements_by_xpath("//tbody/tr/td[6]"):
    Genre.append(i.text)
    
#Creating dataframe for scraped data
Novels=pd.DataFrame({})
Novels['Book Name'] = Book_name
Novels['Author'] = Author_name
Novels['Volume sold'] = Volumes_sold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # 9: Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
# Connecting to the webdriver
driver = webdriver.Chrome(r'C:\Users\Chandru\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url=("https://www.imdb.com/list/ls095964455/")
driver.get(url)

# %%
#Creating empty lists.
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

#Scraping data of Names
for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

#Scraping data of Year span
for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)

#Scraping data of genre
for i in driver.find_elements_by_xpath("//span[@class='genre']"):
    Genre.append(i.text)

#Scraping data of Run time
for i in driver.find_elements_by_xpath("//span[@class='runtime']"):
    Run_time.append(i.text)

#Scraping data of Ratings
for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
#Scraping data of votes
for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)
    
# Creating dataframe for scraped data
TV_series=pd.DataFrame({})
TV_series['Name'] = Name
TV_series['Year Span'] = Year_span
TV_series['Genre'] = Genre
TV_series['Run Time'] = Run_time
TV_series['Ratings'] = Ratings
TV_series['Votes'] = Votes
TV_series
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why     (2017– )  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,956,271
# 1    51 min     8.7    966,073
# 2    44 min     8.1    931,823
# 3    60 min     7.5    278,998
# 4    43 min     7.6    239,169
# ..      ...     ...        ...
# 95   42 min     7.5     47,789
# 96   50 min     7.8     58,514
# 97   42 min     8.1    185,700
# 98   45 min     7.1     39,311
# 99  572 min     8.6    221,979
#
# [100 rows x 6 columns]

# %% [markdown]
# # 10: Details of Datasets from UCI machine learning repositories.
#
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the Show All Dataset page through code

# %%
# Connecting to the webdriver
driver = webdriver.Chrome(r'C:\Users\Chandru\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url=("https://archive.ics.uci.edu/")
driver.get(url)

# %%
# Finding view all dataset button from the webpage
viewall_dataset = driver.find_element_by_xpath("//tbody[1]//tr/td[2]/span[2]/a")    
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(3)

# %%
# Fetching page urls of all datasets 
view_list = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
list_url = view_list.get_attribute("href")           
driver.get(list_url)
time.sleep(3)

# %%
# Fetching urls for each dataset
dataset_url = driver.find_elements_by_xpath("//p[@class='normal']//b/a")    

urls = []     
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
#Creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #Scraping Dataset name
    try: 
        dataset_name = driver.find_element_by_xpath("//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    time.sleep(2)
    
    #Scraping data type
    try:
        data_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(2)
    
    #scraping Task
    try:
        task = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(2)
    
    # Scraping Attribute type
    try:
        attribute_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    time.sleep(2)
    
    # Scraping No of instances
    try:
        instances = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    time.sleep(2)
    
    # Scraping No of attributes
    try:
        attribute = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    time.sleep(2)
    
    # Scraping year
    try:
        year = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(2)

# %%
# Creating dataframe for scraped data
ML=pd.DataFrame({})
ML['Data Name'] = Dataset_name
ML['Data Type'] = Data_type
ML['Task'] = Task
ML['Attribute type'] = Attribute_type
ML['No of instance'] = No_of_instances
ML['No of attributes'] = No_of_attributes
ML['Year'] = Year
ML
# Out:
#                                              Data Name  \
# 0         2.4 GHZ Indoor Channel Measurements Data Set
# 1    3D Road Network (North Jutland, Denmark) Data Set
# 2                                  3W dataset Data Set
# 3                          9mers from cullpdb Data Set
# 4    : Simulated Data set of Iraqi tourism places D...
# ..                                                 ...
# 617  Youtube cookery channels viewers comments in H...
# 618     YouTube Multiview Video Games Dataset Data Set
# 619                   YouTube Spam Collection Data Set
# 620                           Z-Alizadeh Sani Data Set
# 621                                       Zoo Data Set
#
#                      Data Type                        Task  \
# 0                 Multivariate              Classification
# 1             Sequential, Text      Regression, Clustering
# 2    Multivariate, Time-Series  Classification, Clustering
# 3                   Sequential  Classification, Regression
# 4                 Multivariate  Classification, Clustering
# ..                         ...                         ...
# 617         Multivariate, Text              Classification
# 618         Multivariate, Text  Classification, Clustering
# 619                       Text              Classification
# 620                          -              Classification
# 621               Multivariate              Classification
#
#            Attribute type No of instance No of attributes  Year
# 0                    Real           7840                5  2018
# 1                    Real         434874                4  2013
# 2           Integer, Real           1984                8  2019
# 3                    Real         158716                4  2021
# 4                       -            232               16  2020
# ..                    ...            ...              ...   ...
# 617                     -           9800                3  2019
# 618         Integer, Real         120000          1000000  2013
# 619                     -           1956                5  2017
# 620         Integer, Real            303               56  2017
# 621  Categorical, Integer            101               17  1990
#
# [622 rows x 7 columns]
